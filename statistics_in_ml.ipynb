# %% [markdown]
# <a href="https://colab.research.google.com/github/NishmthaM/statistics_in_ml/blob/main/statistics_in_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# setting visual theme for seaborn

sns.set_theme(style="whitegrid")

# %% [markdown]
# 1.loading dataset

# %%
#load tips dataset
df=sns.load_dataset("tips")

# %%
df.head() # for first 5 rows
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.tail() # to get last 5 rows
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# 2.Measure of central tendency

# %%
print(df.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
col=df["total_bill"]

# %%
print(col)
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
print(type(col))
# Out:
# <class 'pandas.core.series.Series'>

# %%
mean_value= col.mean()
print(mean_value)
# Out:
# 19.78594262295082

# %%
mean_val = np.mean(col)
print(mean_val)
# Out:
# 19.78594262295082

# %%
mean_val = np.mean(col)
meadian_val = np.median(col)
mode_val = col.mode()[0]
print(f"mean value is {mean_val:.2f}")
print(f"median value is {meadian_val:.1f}")
print(f"mode value is {mode_val:.0f}")
# Out:
# mean value is 19.79
# median value is 17.8
# mode value is 13

# %%
col=df["total_bill"]

mean_val = np.mean(col)
meadian_val = np.median(col)
mode_val = col.mode()[0]
print(f"mean value is {mean_val:.2f}")
print(f"median value is {meadian_val:.2f}")
print(f"mode value is {mode_val:.2f}")

plt.figure(figsize=(5,3))
sns.histplot(col, kde=True, color="skyblue",)
plt.axvline(mean_val,color='red', linestyle="--", label=f"Mean:{mean_val:.2f}")
plt.axvline(meadian_val,color='green', linestyle="--", label=f"Median:{meadian_val:.2f}")
plt.axvline(mode_val,color='yellow', linestyle="--", label=f"Mode:{mode_val:.2f}")
plt.legend()
plt.title("Distribution of total bill")
plt.show()
# Out:
# mean value is 19.79
# median value is 17.80
# mode value is 13.42

# %%
col1=df["tip"]

mean_val = np.mean(col1)
meadian_val = np.median(col1)
mode_val = col1.mode()[0]
print(f"mean value is {mean_val:.2f}")
print(f"median value is {meadian_val:.2f}")
print(f"mode value is {mode_val:.2f}")

plt.figure(figsize=(5,3))
sns.histplot(col1, kde=True, color="tan",)
plt.axvline(mean_val,color='red', linestyle="--", label=f"Mean:{mean_val:.2f}")
plt.axvline(meadian_val,color='green', linestyle="--", label=f"Median:{meadian_val:.2f}")
plt.axvline(mode_val,color='yellow', linestyle="--", label=f"Mode:{mode_val:.2f}")
plt.legend()
plt.title("Distribution of tip")
plt.show()
# Out:
# mean value is 3.00
# median value is 2.90
# mode value is 2.00

# %% [markdown]
# **Measure of spread**
#
# describe how scattered or varied a dataset is

# %%
#range

data_range=col.max()-col.min()

print(data_range)
# Out:
# 47.74

# %%
#range

data_range=col1.max()-col1.min()

print(data_range)
# Out:
# 9.0

# %%
 # variance

variance=np.var(col)

print(f"variance is {variance:.2f}")
# Out:
# variance is 78.93

# %%
# standard deveation

std=np.std(col)

print(f"standard deviation is {std:.2f}")
# Out:
# standard deviation is 8.88

# %%
# IQR- inter quartile range

Q1 = np.percentile(col, 25)
Q3 = np.percentile(col, 75)

iqr= Q3-Q1

print(f"Q1 = {Q1:.2f}")
print(f"Q3 ={Q3:.2f}")
print(f"IQR ={iqr:.2f}")
# Out:
# Q1 = 13.35
# Q3 =24.13
# IQR =10.78

# %% [markdown]
# **4.summary statistics(df.describe)**

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# ---

# %% [markdown]
# 1.   Data distribution & skewness
# 2.   outlier Detection
# 3.   Correlation analysis

# %% [markdown]
# ---

# %% [markdown]
# 1. Data distribution & skewness

# %%
print(df["tip"].skew())
print(df["total_bill"].skew())
# Out:
# 1.4654510370979401
# 1.1332130376158205

# %%
plt.figure(figsize=(6,3))

plt.subplot(1,2,1)
sns.histplot(df["tip"], kde=True,color="skyblue")
plt.title(f"Distribution on Tips(skew: {df["tip"].skew():.2f})")


plt.subplot(1,2,2)
sns.histplot(df["total_bill"], kde=True,color="skyblue")
plt.title(f"Distribution on Total bill (skew: {df["total_bill"].skew():.2f})")

plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Outlier Detection

# %%
 # visual method

plt.figure( figsize=(5,3) )
sns.boxplot(x=df["total_bill"])
plt.title("Box plot of total bill")
plt.show()
